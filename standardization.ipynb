# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Đọc dữ liệu từ tệp
file_path = '/kaggle/input/newnncc/other/default/1/newncc.csv'
data = pd.read_csv(file_path)

# Danh sách các cột cần chuẩn hóa
columns_to_normalize = [
    'Ti Le Loi', 'Chiet Khau', 'Thoi Gian Giao Hang',  'Quy Mo','Vi Tri','Dich Vu Khach Hang']

# Chuẩn hóa dữ liệu (Min-Max Normalization) sử dụng sklearn
scaler = MinMaxScaler(feature_range=(0, 1))
data_normalized = data.copy()
data_normalized[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])

# Lưu dữ liệu chuẩn hóa vào file CSV
data_normalized.to_csv('newchuanhoa.csv', index=False)
print("Dữ liệu chuẩn hóa đã được lưu vào file 'dulieu_chuanhoa.csv'.")
# Out:
# Dữ liệu chuẩn hóa đã được lưu vào file 'dulieu_chuanhoa.csv'.
